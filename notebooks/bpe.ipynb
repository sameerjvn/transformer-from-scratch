# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from pathlib import Path

# Move up to project root if we're in the notebooks directory
if Path.cwd().name == "notebooks":
    os.chdir("..")

# %%
Path.cwd().name
# Out:
# 'transformer-from-scratch'

# %%
from pathlib import Path
from cs336_basics.bpe import train_bpe, pretokenize
from cs336_basics.pretokenization_example import find_chunk_boundaries
import cProfile
import multiprocessing
from multiprocessing import Pool
import regex as re
from collections import defaultdict

# %%
#dataset_path = Path("data/bpe_example.txt")
#dataset_path = Path("data/TinyStories-valid.txt")
#dataset_path = Path("tests/fixtures/corpus.en")
dataset_path = Path("tests/fixtures/tinystories_sample.txt")
vocab_size = 300
special_tokens = ["<|endoftext|>"]
PAT = re.compile(rb"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+""")

# %%
from cs336_basics.bpe import parallel_pretokenize


def profile():
    train_bpe(dataset_path, vocab_size, special_tokens, parallel=False)

cProfile.run("profile()", sort="cumulative")
# Out:
#          176387 function calls (176386 primitive calls) in 2.986 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.000    0.000    2.986    2.986 {built-in method builtins.exec}
#         1    0.000    0.000    2.986    2.986 <string>:1(<module>)
#         1    0.000    0.000    2.986    2.986 1136238275.py:4(profile)
#         1    0.002    0.002    2.986    2.986 bpe.py:1(train_bpe)
#        43    2.905    0.068    2.918    0.068 bpe.py:30(find_most_frequent_pair)
#        43    0.044    0.001    0.062    0.001 bpe.py:58(merge)
#     83482    0.010    0.000    0.010    0.000 {built-in method builtins.len}
#     36874    0.008    0.000    0.008    0.000 {method 'add' of 'set' objects}
#     26340    0.005    0.000    0.005    0.000 {method 'append' of 'list' objects}
#     15983    0.005    0.000    0.005    0.000 {method 'items' of 'dict' objects}
# ...
