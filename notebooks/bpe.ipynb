# %%
# %cd ..
# Out:
# /Users/sameer/repos/transformer-from-scratch

# %%
from pathlib import Path
from cs336_basics.bpe import train_bpe
import cProfile

# %%
#dataset_path = Path("data/bpe_example.txt")
dataset_path = Path("data/TinyStories-valid.txt")
vocab_size = 500
special_tokens = ["<|endoftext|>"]

# %%
train_bpe(dataset_path, vocab_size, special_tokens)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 train_bpe(dataset_path, vocab_size, special_tokens)
#
# File ~/repos/transformer-from-scratch/cs336_basics/bpe.py:100, in train_bpe(input_path, vocab_size, special_tokens)
#      97 pretokens_to_counts = split_data_into_pretokens_and_counts(data)
#      99 while len(vocab) < vocab_size:
# --> 100     bytes_pair = find_most_frequent_pair(pretokens_to_counts)
#     101     byte_1, byte_2 = bytes_pair
#     103     target_index = max(vocab) + 1
#
# File ~/repos/transformer-from-scratch/cs336_basics/bpe.py:42, in find_most_frequent_pair(pretokens_to_counts)
#      40     for pretoken, count in pretokens_to_counts.items():
#      41         for bp in zip(pretoken, pretoken[1:]):
# ---> 42             if byte_pair == bp:
#      43                 counts[byte_pair] += count
#      46 # find most frequent index pair
#
# KeyboardInterrupt:

# %%
cProfile.run('train_bpe(dataset_path, vocab_size, special_tokens)')
# Out:
#          597 function calls (594 primitive calls) in 0.001 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#       2/1    0.000    0.000    0.001    0.001 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 _local.py:166(__fspath__)
#         1    0.000    0.000    0.000    0.000 _local.py:227(__str__)
#         1    0.000    0.000    0.001    0.001 asyncio.py:206(_handle_events)
#         1    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#         1    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#         1    0.000    0.000    0.000    0.000 base_events.py:1932(_add_callback)
#         1    0.000    0.000    0.000    0.000 base_events.py:768(time)
#         1    0.000    0.000    0.000    0.000 bpe.py:10(split_data_into_pretokens_and_counts)
#        95    0.000    0.000    0.000    0.000 bpe.py:23(<genexpr>)
#         5    0.000    0.000    0.000    0.000 bpe.py:29(find_most_frequent_pair)
#         5    0.000    0.000    0.000    0.000 bpe.py:57(merge)
#       2/1    0.000    0.000    0.001    0.001 bpe.py:80(train_bpe)
#         1    0.000    0.000    0.000    0.000 contextlib.py:108(__init__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:136(__enter__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:303(helper)
#         1    0.000    0.000    0.000    0.000 decorator.py:200(fix)
#         1    0.000    0.000    0.001    0.001 decorator.py:232(fun)
#         4    0.000    0.000    0.000    0.000 enum.py:1145(__new__)
#         6    0.000    0.000    0.000    0.000 enum.py:1574(_get_value)
#         1    0.000    0.000    0.000    0.000 enum.py:1581(__or__)
#         1    0.000    0.000    0.000    0.000 enum.py:1592(__and__)
#         4    0.000    0.000    0.000    0.000 enum.py:691(__call__)
#         1    0.000    0.000    0.001    0.001 events.py:87(_run)
#         1    0.000    0.000    0.000    0.000 history.py:1092(hold)
#         4    0.000    0.000    0.000    0.000 inspect.py:2775(name)
#        10    0.000    0.000    0.000    0.000 inspect.py:2787(kind)
#         1    0.000    0.000    0.000    0.000 inspect.py:2869(__init__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2877(args)
#         1    0.000    0.000    0.000    0.000 inspect.py:2900(kwargs)
#         1    0.000    0.000    0.000    0.000 inspect.py:2930(apply_defaults)
#         4    0.000    0.000    0.000    0.000 inspect.py:3070(parameters)
#         1    0.000    0.000    0.000    0.000 inspect.py:3116(_bind)
#         1    0.000    0.000    0.000    0.000 inspect.py:3255(bind)
#         1    0.000    0.000    0.001    0.001 iostream.py:229(_handle_event)
#         1    0.000    0.000    0.000    0.000 iostream.py:285(_is_master_process)
#         1    0.000    0.000    0.000    0.000 iostream.py:288(_check_mp_mode)
#         1    0.000    0.000    0.000    0.000 iostream.py:327(closed)
#         1    0.000    0.000    0.001    0.001 iostream.py:348(<lambda>)
#         1    0.000    0.000    0.001    0.001 iostream.py:350(_really_send)
#         1    0.000    0.000    0.000    0.000 main.py:243(__init__)
#         1    0.000    0.000    0.000    0.000 selector_events.py:740(_process_events)
#         1    0.000    0.000    0.000    0.000 socket.py:771(recv_multipart)
#         1    0.000    0.000    0.000    0.000 threading.py:303(__enter__)
#         2    0.000    0.000    0.000    0.000 threading.py:306(__exit__)
#         1    0.000    0.000    0.000    0.000 threading.py:315(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 threading.py:631(clear)
#         3    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         3    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         2    0.000    0.000    0.000    0.000 typing.py:1443(__hash__)
#         7    0.000    0.000    0.000    0.000 typing.py:2366(cast)
#         3    0.000    0.000    0.000    0.000 typing.py:426(inner)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:528(receiving)
#         1    0.000    0.000    0.001    0.001 zmqstream.py:546(_run_callback)
#         1    0.000    0.000    0.001    0.001 zmqstream.py:573(_handle_events)
#         1    0.000    0.000    0.001    0.001 zmqstream.py:614(_handle_recv)
#         1    0.000    0.000    0.000    0.000 {built-in method _io.open}
#       2/1    0.000    0.000    0.001    0.001 {built-in method builtins.exec}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#       135    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        60    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        56    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#        15    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        58    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         5    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'read' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'replace' of 'bytes' objects}
#         1    0.000    0.000    0.001    0.001 {method 'run' of '_contextvars.Context' objects}
#         3    0.000    0.000    0.000    0.000 {method 'split' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'splitlines' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'validate_python' of 'pydantic_core._pydantic_core.SchemaValidator' objects}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
