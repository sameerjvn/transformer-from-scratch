# %%
from pathlib import Path
from cs336_basics.bpe import train_bpe, pretokenize
import cProfile

# %%
#dataset_path = Path("data/bpe_example.txt")
#dataset_path = Path("data/TinyStories-valid.txt")
dataset_path = Path("tests/fixtures/corpus.en")
vocab_size = 500
special_tokens = ["<|endoftext|>"]

# %%
with open(dataset_path, "rb") as f:
    data = f.read()

def run():
    for _ in range(500-256):
        pretokenize(data)

cProfile.run("run()", sort="cumulative")
# Out:
#          46069712 function calls (46069606 primitive calls) in 29.180 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    3.862    3.862   25.324   25.324 {built-in method builtins.exec}
#       244   14.134    0.058   25.069    0.103 bpe.py:12(pretokenize)
#         5    0.000    0.000   20.008    4.002 base_events.py:1922(_run_once)
#         5    0.068    0.014   20.008    4.002 selectors.py:451(select)
#  39258624    9.829    0.000    9.829    0.000 bpe.py:19(<genexpr>)
#         1    0.000    0.000    1.453    1.453 <string>:1(<module>)
#         1    0.006    0.006    1.453    1.453 1532789026.py:4(run)
#   6800036    1.167    0.000    1.167    0.000 {method 'group' of '_regex.Match' objects}
#         5    0.082    0.016    0.147    0.029 {method 'poll' of 'select.epoll' objects}
#       244    0.001    0.000    0.023    0.000 regex.py:340(finditer)
#       244    0.007    0.000    0.020    0.000 regex.py:449(_compile)
#         2    0.008    0.004    0.016    0.008 {method '__exit__' of 'sqlite3.Connection' objects}
#       617    0.003    0.000    0.008    0.000 enum.py:1561(__and__)
#      1871    0.002    0.000    0.003    0.000 enum.py:1543(_get_value)
#       625    0.001    0.000    0.002    0.000 enum.py:720(__call__)
#      3464    0.002    0.000    0.002    0.000 {built-in method builtins.isinstance}
#       244    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#       244    0.001    0.000    0.001    0.000 {method 'finditer' of '_regex.Pattern' objects}
#       3/1    0.000    0.000    0.001    0.001 _regex_core.py:417(_parse_pattern)
#      11/6    0.000    0.000    0.001    0.000 _regex_core.py:427(parse_sequence)
#       244    0.001    0.000    0.001    0.000 regex.py:471(complain_unused_args)
#       625    0.001    0.000    0.001    0.000 enum.py:1128(__new__)
#         2    0.000    0.000    0.001    0.000 _regex_core.py:803(parse_paren)
#         1    0.000    0.000    0.000    0.000 _regex_core.py:1121(parse_flags_subpattern)
#       300    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 _regex_core.py:1447(parse_set)
#       252    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         6    0.000    0.000    0.000    0.000 events.py:86(_run)
#         6    0.000    0.000    0.000    0.000 {method 'run' of '_contextvars.Context' objects}
#         8    0.000    0.000    0.000    0.000 _regex_core.py:1192(parse_escape)
#         1    0.000    0.000    0.000    0.000 _regex_core.py:1102(parse_subpattern)
#         2    0.000    0.000    0.000    0.000 _regex_core.py:1513(parse_set_imp_union)
#       2/1    0.000    0.000    0.000    0.000 _regex_core.py:2072(optimise)
#         4    0.000    0.000    0.000    0.000 _regex_core.py:1389(parse_property)
#         3    0.000    0.000    0.000    0.000 iostream.py:190(_run_event_pipe_gc)
#         1    0.000    0.000    0.000    0.000 _regex_core.py:335(_compile_firstset)
#         7    0.000    0.000    0.000    0.000 _regex_core.py:1536(parse_set_member)
#         7    0.000    0.000    0.000    0.000 _regex_core.py:1577(parse_set_item)
#         1    0.000    0.000    0.000    0.000 _regex_core.py:345(_check_firstset)
#      45/2    0.000    0.000    0.000    0.000 _regex_core.py:1928(compile)
#       2/1    0.000    0.000    0.000    0.000 _regex_core.py:2166(_flatten_branches)
#      11/6    0.000    0.000    0.000    0.000 _regex_core.py:3443(optimise)
#         2    0.000    0.000    0.000    0.000 enum.py:1583(__invert__)
#         3    0.000    0.000    0.000    0.000 enum.py:1413(_missing_)
#       2/1    0.000    0.000    0.000    0.000 _regex_core.py:2146(_compile)
#        13    0.000    0.000    0.000    0.000 _regex_core.py:1881(with_flags)
#        15    0.000    0.000    0.000    0.000 _regex_core.py:384(make_case_flags)
#         6    0.000    0.000    0.000    0.000 tasks.py:653(sleep)
#         5    0.000    0.000    0.000    0.000 _regex_core.py:3522(_compile)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        15    0.000    0.000    0.000    0.000 _regex_core.py:2517(__init__)
#         4    0.000    0.000    0.000    0.000 _regex_core.py:1667(lookup_property)
#       2/1    0.000    0.000    0.000    0.000 _regex_core.py:2122(pack_characters)
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#       5/4    0.000    0.000    0.000    0.000 _regex_core.py:3846(optimise)
#       8/5    0.000    0.000    0.000    0.000 _regex_core.py:3455(pack_characters)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         3    0.000    0.000    0.000    0.000 iostream.py:199(_event_pipe_gc)
#        31    0.000    0.000    0.000    0.000 enum.py:1403(_iter_member_by_def_)
#         1    0.000    0.000    0.000    0.000 _regex_core.py:3659(rebuild)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#       4/3    0.000    0.000    0.000    0.000 _regex_core.py:3878(_compile)
#         8    0.000    0.000    0.000    0.000 _regex_core.py:511(apply_quantifier)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         4    0.000    0.000    0.000    0.000 _regex_core.py:1656(standardise_name)
#         1    0.000    0.000    0.000    0.000 _regex_core.py:4365(_get_required_string)
#     11/10    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         3    0.000    0.000    0.000    0.000 futures.py:313(_set_result_unless_cancelled)
#         8    0.000    0.000    0.000    0.000 _regex_core.py:2909(_compile)
#        17    0.000    0.000    0.000    0.000 _regex_core.py:3537(_flush_characters)
#         1    0.000    0.000    0.000    0.000 _regex_core.py:1943(get_required_string)
#         1    0.000    0.000    0.000    0.000 _regex_core.py:2139(get_firstset)
#        49    0.000    0.000    0.000    0.000 _regex_core.py:4196(match)
#         1    0.000    0.000    0.000    0.000 _regex_core.py:946(parse_lookaround)
#         3    0.000    0.000    0.000    0.000 base_events.py:747(call_later)
#       2/1    0.000    0.000    0.000    0.000 _regex_core.py:2452(max_width)
#         2    0.000    0.000    0.000    0.000 _regex_core.py:2179(_split_common_prefix)
#      12/7    0.000    0.000    0.000    0.000 _regex_core.py:2453(<genexpr>)
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         6    0.000    0.000    0.000    0.000 enum.py:1550(__or__)
#         3    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         5    0.000    0.000    0.000    0.000 _regex_core.py:3506(get_firstset)
#         5    0.000    0.000    0.000    0.000 _regex_core.py:3626(max_width)
#         9    0.000    0.000    0.000    0.000 threading.py:1222(is_alive)
#         2    0.000    0.000    0.000    0.000 _regex_core.py:2346(_reduce_to_set)
#        31    0.000    0.000    0.000    0.000 enum.py:1393(_iter_member_by_value_)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         1    0.000    0.000    0.000    0.000 locale.py:667(getpreferredencoding)
#         3    0.000    0.000    0.000    0.000 base_events.py:771(call_at)
#       204    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#        15    0.000    0.000    0.000    0.000 _regex_core.py:3627(<genexpr>)
#         4    0.000    0.000    0.000    0.000 _regex_core.py:410(make_property)
#         3    0.000    0.000    0.000    0.000 events.py:155(cancel)
#         4    0.000    0.000    0.000    0.000 _regex_core.py:1635(numeric_to_rational)
#         3    0.000    0.000    0.000    0.000 base_events.py:789(call_soon)
#        12    0.000    0.000    0.000    0.000 base_events.py:738(time)
#         3    0.000    0.000    0.000    0.000 locale.py:600(setlocale)
#         8    0.000    0.000    0.000    0.000 _regex_core.py:2902(get_firstset)
#         1    0.000    0.000    0.000    0.000 _regex_core.py:1085(parse_flags)
#         2    0.000    0.000    0.000    0.000 _regex_core.py:376(_flatten_code)
#         1    0.000    0.000    0.000    0.000 {built-in method regex._regex.compile}
#        16    0.000    0.000    0.000    0.000 _regex_core.py:2871(__init__)
#        94    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#        22    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#     26/16    0.000    0.000    0.000    0.000 _regex_core.py:1934(__hash__)
#       120    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        71    0.000    0.000    0.000    0.000 _regex_core.py:4053(get)
#         3    0.000    0.000    0.000    0.000 {built-in method _locale.setlocale}
#         3    0.000    0.000    0.000    0.000 events.py:111(__init__)
#         6    0.000    0.000    0.000    0.000 events.py:36(__init__)
#         3    0.000    0.000    0.000    0.000 base_events.py:818(_call_soon)
#         8    0.000    0.000    0.000    0.000 _regex_core.py:2880(optimise)
#        11    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        21    0.000    0.000    0.000    0.000 _regex_core.py:1871(make_sequence)
#         4    0.000    0.000    0.000    0.000 _regex_core.py:3645(__init__)
#        69    0.000    0.000    0.000    0.000 _regex_core.py:1878(__init__)
#         4    0.000    0.000    0.000    0.000 _regex_core.py:2546(_compile)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         9    0.000    0.000    0.000    0.000 threading.py:1155(_wait_for_tstate_lock)
#       2/1    0.000    0.000    0.000    0.000 _regex_core.py:2068(fix_groups)
#         1    0.000    0.000    0.000    0.000 _regex_core.py:4264(__init__)
#         4    0.000    0.000    0.000    0.000 _regex_core.py:1425(parse_property_name)
#         5    0.000    0.000    0.000    0.000 _regex_core.py:3691(_handle_case_folding)
#        49    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#      11/6    0.000    0.000    0.000    0.000 _regex_core.py:3439(fix_groups)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         3    0.000    0.000    0.000    0.000 _regex_core.py:3943(__init__)
#        31    0.000    0.000    0.000    0.000 enum.py:117(_iter_bits_lsb)
#        24    0.000    0.000    0.000    0.000 _regex_core.py:3432(__init__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#        11    0.000    0.000    0.000    0.000 _regex_core.py:2400(_flush_set_members)
#         3    0.000    0.000    0.000    0.000 base_events.py:446(create_future)
#     26/16    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         6    0.000    0.000    0.000    0.000 _regex_core.py:2197(<genexpr>)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         1    0.000    0.000    0.000    0.000 history.py:1039(_writeout_output_cache)
#        14    0.000    0.000    0.000    0.000 _regex_core.py:3271(_compile)
#         1    0.000    0.000    0.000    0.000 _regex_core.py:4041(__init__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#        28    0.000    0.000    0.000    0.000 enum.py:1410(<lambda>)
#         4    0.000    0.000    0.000    0.000 _regex_core.py:2540(get_firstset)
#        12    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         8    0.000    0.000    0.000    0.000 _regex_core.py:559(parse_quantifier)
#         4    0.000    0.000    0.000    0.000 _regex_core.py:4119(get_while)
#         1    0.000    0.000    0.000    0.000 _regex_core.py:1069(parse_flag_set)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         4    0.000    0.000    0.000    0.000 _regex_core.py:3246(__init__)
#         3    0.000    0.000    0.000    0.000 events.py:72(cancel)
#         4    0.000    0.000    0.000    0.000 _regex_core.py:3265(get_firstset)
#         9    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 _regex_core.py:3721(max_width)
#         8    0.000    0.000    0.000    0.000 _regex_core.py:2940(max_width)
#         1    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         4    0.000    0.000    0.000    0.000 _regex_core.py:2064(__init__)
#         3    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#         1    0.000    0.000    0.000    0.000 _regex_core.py:3120(_compile)
#         3    0.000    0.000    0.000    0.000 _regex_core.py:3971(_compile)
#         8    0.000    0.000    0.000    0.000 _regex_core.py:2885(pack_characters)
#         2    0.000    0.000    0.000    0.000 _regex_core.py:3082(__init__)
#         2    0.000    0.000    0.000    0.000 _regex_core.py:4235(expect)
#         3    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0xaab860}
#         1    0.000    0.000    0.000    0.000 _regex_core.py:3663(get_firstset)
#         7    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         3    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         5    0.000    0.000    0.000    0.000 _regex_core.py:1937(__eq__)
#         1    0.000    0.000    0.000    0.000 _regex_core.py:3091(optimise)
#         9    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#        14    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         5    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         4    0.000    0.000    0.000    0.000 _regex_core.py:2573(max_width)
#        12    0.000    0.000    0.000    0.000 _regex_core.py:2191(<genexpr>)
#         8    0.000    0.000    0.000    0.000 _regex_core.py:2877(fix_groups)
#        15    0.000    0.000    0.000    0.000 {built-in method builtins.chr}
#         3    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         4    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         3    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         6    0.000    0.000    0.000    0.000 selector_events.py:750(_process_events)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         2    0.000    0.000    0.000    0.000 _regex_core.py:2107(_add_precheck)
#         8    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 _regex_core.py:1661(<genexpr>)
#         6    0.000    0.000    0.000    0.000 base_events.py:543(_check_closed)
#         3    0.000    0.000    0.000    0.000 base_events.py:1917(_timer_handle_cancelled)
#         3    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#         6    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         4    0.000    0.000    0.000    0.000 _regex_core.py:3236(_compile)
#        12    0.000    0.000    0.000    0.000 base_events.py:2017(get_debug)
#      11/2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        17    0.000    0.000    0.000    0.000 _regex_core.py:3262(optimise)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         3    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#        16    0.000    0.000    0.000    0.000 _regex_core.py:2537(optimise)
#         3    0.000    0.000    0.000    0.000 _regex_core.py:3985(max_width)
#         1    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         4    0.000    0.000    0.000    0.000 _regex_core.py:3746(__del__)
#        17    0.000    0.000    0.000    0.000 _regex_core.py:1901(fix_groups)
#         1    0.000    0.000    0.000    0.000 {built-in method _locale.getencoding}
#         1    0.000    0.000    0.000    0.000 _regex_core.py:4326(_check_group_features)
#         1    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         4    0.000    0.000    0.000    0.000 _regex_core.py:3233(__init__)
#        12    0.000    0.000    0.000    0.000 typing.py:2187(cast)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         8    0.000    0.000    0.000    0.000 _regex_core.py:1931(is_empty)
#         3    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 _regex_core.py:3088(fix_groups)
#        10    0.000    0.000    0.000    0.000 _regex_core.py:1907(pack_characters)
#         1    0.000    0.000    0.000    0.000 _regex_core.py:3098(pack_characters)
#         1    0.000    0.000    0.000    0.000 _regex_core.py:4239(at_end)
#         1    0.000    0.000    0.000    0.000 _regex_core.py:2935(__eq__)
#         1    0.000    0.000    0.000    0.000 history.py:1092(hold)
#         1    0.000    0.000    0.000    0.000 _regex_core.py:1925(has_simple_start)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 _regex_core.py:1916(can_be_affix)
#         1    0.000    0.000    0.000    0.000 regex.py:642(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _regex_core.py:3144(max_width)

# %%
#train_bpe(dataset_path, vocab_size, special_tokens)

# %%
#cProfile.run('train_bpe(dataset_path, vocab_size, special_tokens)')

# %%
from cs336_basics.pretokenization_example import find_chunk_boundaries


with open(dataset_path, "rb") as f:
    num_processes = 4
    boundaries = find_chunk_boundaries(f, num_processes, b"<|endoftext|>")

    # The following is a serial implementation, but you can parallelize this
    # by sending each start/end pair to a set of processes.
    for start, end in zip(boundaries[:-1], boundaries[1:]):
        f.seek(start)
        chunk = f.read(end - start).decode("utf-8", errors="ignore")
        # Run pre-tokenization on your chunk and store the counts for each pre-token
